# %% [markdown]
# ## Exploracion de datasets

# %%
import pandas as pd

# %%
primera_vuelta = pd.concat([pd.read_csv('./FMESPR_0101.csv', delimiter = ';'),
                            pd.read_csv('./FMESPR_0202.csv', delimiter = ';'),
                            pd.read_csv('./FMESPR_0313.csv', delimiter = ';'),
                            pd.read_csv('./FMESPR_1424.csv', delimiter = ';')])

# %%
# votos por lista
x = primera_vuelta.groupby('CODIGO VOTOS').sum()['VOTOS']
x.sort_values(ascending = False)/x.sum()
# Out:
# CODIGO VOTOS
# 9001    0.391681
# 9002    0.297199
# 131     0.111039
# 135     0.103396
# 138     0.064284
# 137     0.009843
# 132     0.007636
# 9004    0.007352
# 133     0.005023
# 9005    0.002327
# 9006    0.000117
# 9003    0.000104
# Name: VOTOS, dtype: float64

# %%
segunda_vuelta = pd.concat([pd.read_csv('./PV_0101.csv', delimiter = ';'),
                            pd.read_csv('./PV_0202.csv', delimiter = ';'),
                            pd.read_csv('./PV_0313.csv', delimiter = ';'),
                            pd.read_csv('./PV_1424.csv', delimiter = ';')])

# %%
x = segunda_vuelta.groupby(['CODIGO VOTOS']).sum()[['VOTOS']]
100*x/x.sum().sort_index()
# Out:
#                   VOTOS
# CODIGO VOTOS
# 131           14.788326
# 135           15.642837
# 9001          38.576931
# 9002          30.219883
# 9003           0.006824
# 9004           0.370033
# 9005           0.385765
# 9006           0.009400

# %%
# Diputados

dip_nac = pd.concat([pd.read_csv('./FMESDN_0101.csv', delimiter = ';'),
                            pd.read_csv('./FMESDN_0202.csv', delimiter = ';'),
                            pd.read_csv('./FMESDN_0313.csv', delimiter = ';'),
                            pd.read_csv('./FMESDN_1424.csv')])

# %%
# dip_nac.groupby(['CODIGO VOTOS'])['VOTOS'].sum().sort_values()

# Total de mesas y votos por circuito
segunda_vuelta.groupby(['CODIGO PROVINCIA', 'CODIGO DEPARTAMENTO', 'CODIGO CIRCUITO   ',]).agg({
        'CODIGO MESA': 'count', 'VOTOS': 'sum'})
# Out:
#                                                          VOTOS  CODIGO MESA
# CODIGO PROVINCIA CODIGO DEPARTAMENTO CODIGO CIRCUITO
# 1                1                   1                   25878          248
#                                      2                   24666          232
#                                      3                    4829           48
#                                      4                    5185           48
#                                      5                   17771          184
#                                      6                   39350          368
#                                      7                   19837          192
#                                      8                   19880          208
#                                      9                   26304          264
#                                      10                  29357          280
#                                      11                  29728          296
#                                      12                  28070          272
#                                      13                  30936          296
#                                      14                  12578          120
#                                      15                  19367          200
#                                      16                  20340          192
#                                      17                  28826          272
#                                      18                  18546          176
#                                      19                  27121          256
#                  2                   20                  19694          184
#                                      21                  33087          320
#                                      22                  41448          384
#                                      23                  51589          472
#                                      24                  33819          312
#                                      25                  32845          304
#                                      26                  42022          392
#                                      27                  32590          304
#                                      28                  44348          416
#                                      29                  30751          280
#                  3                   30                  28134          272
# ...                                                        ...          ...
# 23               16                  0228A               35993          312
#                                      0229                24142          216
#                  17                  0230                 2180           24
#                                      0231                 1055           16
#                                      0232                 6443           64
#                                      0233                15760          136
#                                      0234                 8448           72
# 24               1                   0001                14802          176
#                                      0002                 9269          104
#                                      0003                16949          184
#                                      0004                28524          320
#                                      0005                35454          392
#                                      0006                28075          312
#                                      0007                  223            8
#                  2                   0008                40893          432
#                                      0009                17704          192
#                                      0010                47600          512
#                                      0011                 6935           80
#                                      0012                10896          128
#                                      0013                18727          200
#                                      0014                25682          264
#                                      0015                  975           16
#                                      0016                  114            8
#                                      0021                 9312          104
#                  3                   0022                   72            8
#                                      0023                  283            8
#                                      0024                  173            8
#                                      0025                  163            8
#                                      0027                   45            8
#                                      0028                   71            8
#
# [5588 rows x 2 columns]

# %%
votos_por_circuito = segunda_vuelta.groupby(['CODIGO PROVINCIA', 'CODIGO DEPARTAMENTO', 'CODIGO CIRCUITO   ', 'CODIGO VOTOS',])['VOTOS'].sum().reset_index()
votos_por_circuito.sample(10)
# Out:
#        CODIGO PROVINCIA  CODIGO DEPARTAMENTO CODIGO CIRCUITO     CODIGO VOTOS  \
# 2448                  2                   15              0148            131
# 26842                13                    4              0034           9001
# 4626                  2                   55              0420           9001
# 8133                  2                  100              0746A          9004
# 31999                17                    5              0024D          9006
# 21878                 8                   15              0274           9005
# 12751                 4                    5              0068           9006
# 20770                 8                    7              0138           9001
# 7314                  2                   87              0748B          9001
# 8445                  2                  105              0882           9004
#
#        VOTOS
# 2448    6358
# 26842  27763
# 4626     615
# 8133       4
# 31999      0
# 21878     97
# 12751      0
# 20770    901
# 7314   15032
# 8445       4

# %% [markdown]
# ## Shapefile de circuitos electorales

# %%
import geopandas as gpd
df_list = []

for n in range(24):
    try:
        df_list += [gpd.read_file('./circuitos/circuito_'+str(n).zfill(2)+'/circuito_'+str(n).zfill(2)+'.shp')]
    except:
        pass
circuitos = pd.concat(df_list)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(1, figsize = (15, 20))
circuitos.sort_values(by = ['circuito']).plot(ax = ax)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(1, figsize = (20, 8))
ax.hist(primera_vuelta.loc[primera_vuelta['CODIGO VOTOS'] == 9001]['VOTOS'], range(400), linewidth = 0)
ax.hist(primera_vuelta.loc[primera_vuelta['CODIGO VOTOS'] == 9002]['VOTOS'], range(400), linewidth = 0)
ax.hist(primera_vuelta.loc[primera_vuelta['CODIGO VOTOS'] == 131]['VOTOS'], range(400), linewidth = 0, alpha = .5)
ax.hist(primera_vuelta.loc[(primera_vuelta['CODIGO VOTOS'] == 135)]['VOTOS'], range(400), linewidth = 0, alpha = .5)
plt.ylim(0, 5000)
plt.show()

# %%
segunda_vuelta['CODIGO VOTOS'].unique()
# Out:
# array([9001, 9002, 9003, 9004, 9005, 9006,  131,  135])

# %%
fig, ax = plt.subplots(1, figsize = (20, 8))
ax.hist(segunda_vuelta.loc[segunda_vuelta['CODIGO VOTOS'] == 9001]['VOTOS'], range(400), linewidth = 0)
ax.hist(segunda_vuelta.loc[segunda_vuelta['CODIGO VOTOS'] == 9002]['VOTOS'], range(400), linewidth = 0)
ax.hist(segunda_vuelta.loc[(segunda_vuelta['CODIGO VOTOS'] == 131) |
                          (segunda_vuelta['CODIGO VOTOS'] == 135)]['VOTOS'], range(400), linewidth = 0)
plt.show()

# %% [markdown]
# ## Unir circuitos con votos

# %%
#Debugging para tratar de que matcheen los circuitos entre la tabla de shapefiles y la de conteo de votos.

circuitos.loc[circuitos.distrito.isin(['02'])].circuito.str.len().value_counts()#.iloc[:, :-1].nunique()
# Out:
# 4    932
# 5    249
# Name: circuito, dtype: int64

# %%
votos_por_circuito.loc[votos_por_circuito['CODIGO PROVINCIA'].isin([1, 2])].drop_duplicates().sample(5)#.reset_index().nunique()
# Out:
#       CODIGO PROVINCIA  CODIGO DEPARTAMENTO CODIGO CIRCUITO     CODIGO VOTOS  \
# 1103                 1                   13                138          9006
# 3562                 2                   35              0773A          9001
# 1000                 1                   12                126           131
# 3647                 2                   36              0287C          9006
# 4402                 2                   52              0382           9001
#
#       VOTOS
# 1103     10
# 3562  55567
# 1000   4975
# 3647      0
# 4402   6269

# %%
# Veamos que tan largos son los codigos de circuito segun la provincia, para ver si hace falta agregar un cero delante o algo asi...

votos_por_circuito.loc[votos_por_circuito['CODIGO PROVINCIA'] == [2]][[
        'CODIGO PROVINCIA', 'CODIGO DEPARTAMENTO', 'circuito']].drop_duplicates()['circuito'].str.strip().str.len().value_counts()
# Out:
# 4    829
# 5    242
# Name: circuito, dtype: int64

# %% [markdown]
# ### Ahora si...

# %%
## Conclusion, definir las siguientes columnas:

votos_por_circuito['circuito'] = votos_por_circuito['CODIGO CIRCUITO   '].astype(str).str.strip().str.zfill(4)
votos_por_circuito['distrito'] = votos_por_circuito['CODIGO PROVINCIA'].astype(str).str.zfill(2)

merged = votos_por_circuito.merge(circuitos[['circuito', 'distrito','geometry']])

#pasar a porcentajes:

merged['VOTOS_pct'] = merged.groupby(['distrito', 'circuito'])['VOTOS'].apply(lambda x: 100*x/x.sum())

# %%
BA = merged.loc[votos_por_circuito['distrito'].isin(['01', '02'])]

fig, ax = plt.subplots(1, figsize = (15, 20))
gpd.GeoDataFrame(BA.loc[BA['CODIGO VOTOS'] == 135]).plot(column='VOTOS_pct', ax = ax, linewidth = 0, cmap='OrRd')

# %%
fig, ax = plt.subplots(1, figsize = (17, 18))
gpd.GeoDataFrame(BA.loc[BA['CODIGO VOTOS'] == 135]).plot(column='VOTOS_pct', ax = ax, linewidth = 0, cmap='Blues', alpha = .5)
gpd.GeoDataFrame(BA.loc[BA['CODIGO VOTOS'] == 131]).plot(column='VOTOS_pct', ax = ax, linewidth = 0, cmap='Reds', alpha = .4)
ax.set_xlim(-59, -57.8)
ax.set_ylim(-35.2, -34)
# Out:
# (-35.2, -34)
