# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline

pd.options.display.max_rows = 600
pd.options.display.max_colwidth = 600

# %%
gdf = gpd.read_file('./data/circuitos/circuito_01/circuito_01.shp')

# %%
fig, ax = plt.subplots(1)
gdf.plot(ax = ax)
gdf.loc[gdf['circuito'] == '0129'].plot(color = 'r', ax = ax)
plt.show()
# 129 - 5430

# %%
gdf.head()
# Out:
#    gid distrito                        provincia departamen   cabecera  \
# 0    3       01  Ciudad Áutonoma de Buenos Aires   Comuna 1   Comuna 1
# 1   42       01  Ciudad Áutonoma de Buenos Aires   Comuna 4   Comuna 4
# 2   34       01  Ciudad Áutonoma de Buenos Aires   Comuna 3   Comuna 3
# 3   17       01  Ciudad Áutonoma de Buenos Aires   Comuna 1   Comuna 1
# 4  164       01  Ciudad Áutonoma de Buenos Aires  Comuna 13  Comuna 13
#
#   circuito indec_p indec_d                                           geometry
# 0     0003      02     001  POLYGON ((-58.35729 -34.59511, -58.35723 -34.5...
# 1     0045      02     004  POLYGON ((-58.40155 -34.64686, -58.40274 -34.6...
# 2     0037      02     003  POLYGON ((-58.40097 -34.61867, -58.40350 -34.6...
# 3     0018      02     001  POLYGON ((-58.38001 -34.62214, -58.38001 -34.6...
# 4     0141      02     013  POLYGON ((-58.42519 -34.54914, -58.42513 -34.5...

# %%
df = pd.read_csv('./data/escrutinio/2017/FMESDN_0101.csv', ';')
df.head()
df.loc[df['CODIGO MESA'] == 5430]
# Out:
#        CODIGO PROVINCIA  CODIGO DEPARTAMENTO  CODIGO CIRCUITO     CODIGO MESA  \
# 64956                 1                   12                 129         5430
# 64957                 1                   12                 129         5430
# 64958                 1                   12                 129         5430
# 64959                 1                   12                 129         5430
# 64960                 1                   12                 129         5430
# 64961                 1                   12                 129         5430
# 64962                 1                   12                 129         5430
# 64963                 1                   12                 129         5430
# 64964                 1                   12                 129         5430
# 64965                 1                   12                 129         5430
# 64966                 1                   12                 129         5430
# ...

# %%
cod = pd.read_csv('./data/codigos/COD_PARTIDOS_2017.csv', encoding = 'latin-1', sep = ';')
# cod = pd.read_csv('./data/codigos/COD_PARTIDOS_2017.csv', encoding = 'latin-1', sep = ';')
cod.columns
# Out:
# Index(['Código Partido', 'Denominacion', 'Lista Interna', 'Agrupación'], dtype='object')

# %%
df.loc[df['CODIGO MESA'] == 5430].merge(cod, left_on =['CODIGO VOTOS'], right_on = 'Código Partido')[['CODIGO MESA', 'Denominacion', 'VOTOS']]
# Out:
#     CODIGO MESA  \
# 0          5430
# 1          5430
# 2          5430
# 3          5430
# 4          5430
# 5          5430
# 6          5430
# 7          5430
# 8          5430
# 9          5430
# 10         5430
# 11         5430
#
#                                                                                             Denominacion  \
# 0   ELECTORES
# 1   VOTANTES
# 2   VOTOS IMPUGNADOS
# 3   VOTOS BLANCOS
# 4   VOTOS NULOS
# 5   VOTOS RECURRIDOS
# 6   AUTODETERMINACION Y LIBERTAD
# 7   UNIDAD PORTEÑA
# 8   VAMOS JUNTOS
# 9   EVOLUCION
# 10  FRENTE DE IZQUIERDA Y DE LOS TRABAJADORES
# 11  AVANCEMOS HACIA 1PAIS MEJOR
#
#     VOTOS
# 0     348
# 1     287
# 2       0
# 3       0
# 4       4
# 5       0
# 6      17
# 7      55
# 8     144
# 9      37
# 10     14
# 11     16

# %%
df.loc[df['CODIGO DEPARTAMENTO'] == 12].groupby(['CODIGO PROVINCIA','CODIGO DEPARTAMENTO', 'CODIGO CIRCUITO   ','CODIGO MESA'])[['VOTOS']].sum()
# Out:
#                                                                      VOTOS
# CODIGO PROVINCIA CODIGO DEPARTAMENTO CODIGO CIRCUITO    CODIGO MESA
# 1                12                  124                5108           911
#                                                         5109           936
#                                                         5110           922
#                                                         5111           909
#                                                         5112           920
#                                                         5113           901
#                                                         5114           919
#                                                         5115           905
#                                                         5116           935
#                                                         5117           919
#                                                         5118           945
# ...

# %%
df.columns
# Out:
# Index(['CODIGO PROVINCIA', 'CODIGO DEPARTAMENTO', 'CODIGO CIRCUITO   ',
#        'CODIGO MESA', 'AMBITO', 'CODIGO VOTOS', 'VOTOS'],
#       dtype='object')
